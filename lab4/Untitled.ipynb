# %%
import threading
import random
import time


latest_temperatures=dict()

def simulate_sensor(location):
    random_temp=random.randint(15,40)
    latest_temperatures.update({location:random_temp})
    print(latest_temperatures)





city=['Doha', 'Alkor', 'AlWakra','RasLaffan']

while True :
    picked_city=random.choice(city)
    time.sleep(1)
    simulate_sensor(picked_city)



def process_temperatures (city):
    for i in city.values():
# Out:
# {'Alkor': 39}
# {'Alkor': 39, 'Doha': 39}
# {'Alkor': 23, 'Doha': 39}
# {'Alkor': 23, 'Doha': 39, 'AlWakra': 23}
# {'Alkor': 23, 'Doha': 23, 'AlWakra': 23}
# {'Alkor': 23, 'Doha': 23, 'AlWakra': 40}
# {'Alkor': 23, 'Doha': 23, 'AlWakra': 40, 'RasLaffan': 19}
# {'Alkor': 23, 'Doha': 23, 'AlWakra': 39, 'RasLaffan': 19}
# {'Alkor': 23, 'Doha': 36, 'AlWakra': 39, 'RasLaffan': 19}
# {'Alkor': 23, 'Doha': 16, 'AlWakra': 39, 'RasLaffan': 19}
# {'Alkor': 23, 'Doha': 16, 'AlWakra': 39, 'RasLaffan': 19}
# {'Alkor': 23, 'Doha': 18, 'AlWakra': 39, 'RasLaffan': 19}
# {'Alkor': 23, 'Doha': 18, 'AlWakra': 39, 'RasLaffan': 20}
# {'Alkor': 34, 'Doha': 18, 'AlWakra': 39, 'RasLaffan': 20}
# {'Alkor': 34, 'Doha': 18, 'AlWakra': 39, 'RasLaffan': 25}
# {'Alkor': 34, 'Doha': 27, 'AlWakra': 39, 'RasLaffan': 25}
# {'Alkor': 34, 'Doha': 27, 'AlWakra': 18, 'RasLaffan': 25}
# {'Alkor': 34, 'Doha': 27, 'AlWakra': 35, 'RasLaffan': 25}
# {'Alkor': 34, 'Doha': 21, 'AlWakra': 35, 'RasLaffan': 25}
# ...
