# %%
import random
import time
import threading
import os
import queue

# Global variables for shared data
latest_temperature = None
temperature_averages = []
temperature_queue = queue.Queue()

# Synchronization tools
lock = threading.Lock()  # Simple lock for synchronizing access to shared resources
condition = threading.Condition(lock)

# City name
city = 'Doha'  # The city for temperature simulation

# Function to simulate temperature readings for a city
def simulate_city_temperature():
    """
    Simulates temperature readings for the city.
    Updates the latest_temperature variable every second.
    """
    global latest_temperature
    while True:
        temperature = random.randint(15, 40)  # Random temperature between 15 and 40
        with lock:
            latest_temperature = temperature
            temperature_queue.put(temperature)  # Add the temperature to the queue
            print(f"[SIMULATION] Latest Temperature Updated: {latest_temperature}")  # Debugging print
            condition.notify_all()  # Notify the display thread that the temperature was updated
        time.sleep(1)  # Simulate a delay of 1 second for each city reading

# Function to process temperatures and calculate averages
def process_temperatures():
    """
    Processes temperatures in the queue and calculates the average temperature.
    Updates the temperature_averages list every 5 seconds.
    """
    while True:
        time.sleep(5)  # Process every 5 seconds
        with lock:
            # Update the average temperature
            if temperature_queue.qsize() > 0:
                temperature_averages.append(temperature_queue.get())
            if len(temperature_averages) > 0:
                avg_temp = sum(temperature_averages) / len(temperature_averages)
            else:
                avg_temp = '--'
            temperature_averages[:] = [avg_temp]  # Update the average in place
            print(f"[PROCESS] Average Temperature Updated: {avg_temp}")  # Debugging print

def process_temperatures():
    """
    Processes temperatures in the queue and calculates the average temperature.
    Updates the temperature_averages list every 5 seconds.
    """
    while True:
        time.sleep(5)  # Process every 5 seconds
        with lock:
            # Collect all temperatures from the queue
            temperatures = []
            while not temperature_queue.empty():
                temperatures.append(temperature_queue.get())
            
            # Calculate the average temperature
            if temperatures:
                avg_temp = sum(temperatures) / len(temperatures)
                temperature_averages.append(avg_temp)
                print(f"[PROCESS] Average Temperature Updated: {avg_temp}")  # Debugging print


#Function to update the display with the latest temperature and average
def update_display():
    """
    Updates the display with the latest temperature and the average in place.
    """
    while True:
        with lock:
            # Wait until the latest temperature is updated
            condition.wait_for(lambda: latest_temperature is not None)
            os.system('cls' if os.name == 'nt' else 'clear')  # Clear the console screen
            print("Current temperature for city:")
            # Display the latest temperature and average
            print(f"Latest Temperature: {latest_temperature}°C")
            avg_temp = temperature_averages[0] if len(temperature_averages) > 0 else '--'
            print(f"{city} Average: {avg_temp}°C")
        time.sleep(1)  # Refresh the display every 1 second




# Main program to start all threads and simulation
import random
import time
import threading
import os
import queue

# Global variables for shared data
latest_temperature = None
temperature_averages = []
temperature_queue = queue.Queue()

# Synchronization tools
lock = threading.Lock()  # Simple lock for synchronizing access to shared resources
condition = threading.Condition(lock)

# City name
city = 'Doha'  # The city for temperature simulation

# Function to simulate temperature readings for a city
def simulate_city_temperature():
    """
    Simulates temperature readings for the city.
    Updates the latest_temperature variable every second.
    """
    global latest_temperature
    while True:
        temperature = random.randint(15, 40)  # Random temperature between 15 and 40
        with lock:
            latest_temperature = temperature
            temperature_queue.put(temperature)  # Add the temperature to the queue
            print(f"[SIMULATION] Latest Temperature Updated: {latest_temperature}")  # Debugging print
            condition.notify_all()  # Notify the display thread that the temperature was updated
        time.sleep(1)  # Simulate a delay of 1 second for each city reading

# Function to process temperatures and calculate averages
def process_temperatures():
    """
    Processes temperatures in the queue and calculates the average temperature.
    Updates the temperature_averages list every 5 seconds.
    """
    while True:
        time.sleep(5)  # Process every 5 seconds
        with lock:
            # Collect all temperatures from the queue
            temperatures = []
            while not temperature_queue.empty():
                temperatures.append(temperature_queue.get())
            
            # Calculate the average temperature
            if temperatures:
                avg_temp = sum(temperatures) / len(temperatures)
                temperature_averages.append(avg_temp)
                print(f"[PROCESS] Average Temperature Updated: {avg_temp}")  # Debugging print

# Function to initialize the display layout
def initialize_display():
    """
    Initializes the display layout for showing current temperatures.
    """
    os.system('cls' if os.name == 'nt' else 'clear')  # Clear the console screen
    print("Current temperature for city:")
    print(f"Latest Temperature: --°C")
    print(f"{city} Average: --°C")

# Function to update the display with the latest temperature and average
def update_display():
    """
    Updates the display with the latest temperature and the rolling average.
    """
    while True:
        with lock:
            # Wait until the latest temperature is updated
            condition.wait_for(lambda: latest_temperature is not None)
            os.system('cls' if os.name == 'nt' else 'clear')  # Clear the console screen
            print("Current temperature for city:")
            # Display the latest temperature and rolling average
            print(f"Latest Temperature: {latest_temperature}°C")
            if temperature_averages:
                rolling_avg = sum(temperature_averages[-5:]) / len(temperature_averages[-5:])
                print(f"{city} Rolling Average (last 5 readings): {rolling_avg:.2f}°C")
            else:
                print(f"{city} Rolling Average: --°C")
        time.sleep(1)  # Refresh the display every 1 second

# Main program to start all threads and simulation
def main():
    # Initialize display
    initialize_display()
    
    # Create and start the city temperature simulation thread
    city_thread = threading.Thread(target=simulate_city_temperature, name="CitySimulationThread")
    city_thread.daemon = True  # Daemonize the thread so it terminates when the main program ends
    city_thread.start()

    # Create and start the processing thread
    process_thread = threading.Thread(target=process_temperatures, name="ProcessingThread")
    process_thread.daemon = True
    process_thread.start()

    # Create and start the display update thread
    display_thread = threading.Thread(target=update_display, name="DisplayThread")
    display_thread.daemon = True
    display_thread.start()

    try:
        # Keep the main thread running to allow daemon threads to continue
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        print("\nShutting down gracefully...")

if __name__ == '__main__': 
    main()
# Out:
# Current temperature for city:
# Latest Temperature: --°C
# Doha Average: --°C
# [SIMULATION] Latest Temperature Updated: 22
# Current temperature for city:
# Latest Temperature: 22°C
# Doha Rolling Average: --°C
# [SIMULATION] Latest Temperature Updated: 40
# Current temperature for city:
# Latest Temperature: 40°C
# Doha Rolling Average: --°C
# [SIMULATION] Latest Temperature Updated: 26
# Current temperature for city:
# Latest Temperature: 26°C
# Doha Rolling Average (last 5 readings): 22.00°C
# [SIMULATION] Latest Temperature Updated: 16
# Current temperature for city:
# Latest Temperature: 16°C
# Doha Rolling Average (last 5 readings): 25.25°C
# [SIMULATION] Latest Temperature Updated: 30
# Current temperature for city:
# Latest Temperature: 30°C
# Doha Rolling Average (last 5 readings): 22.33°C
# [PROCESS] Average Temperature Updated: 25.571428571428573
# [SIMULATION] Latest Temperature Updated: 21
# Current temperature for city:
# Latest Temperature: 21°C
# Doha Rolling Average (last 5 readings): 23.14°C
# [SIMULATION] Latest Temperature Updated: 16
# Current temperature for city:
# Latest Temperature: 16°C
# Doha Rolling Average (last 5 readings): 23.14°C
# [SIMULATION] Latest Temperature Updated: 39
# Current temperature for city:
# Latest Temperature: 39°C
# Doha Rolling Average (last 5 readings): 22.71°C
# [SIMULATION] Latest Temperature Updated: 32
# Current temperature for city:
# Latest Temperature: 32°C
# Doha Rolling Average (last 5 readings): 25.26°C
# [SIMULATION] Latest Temperature Updated: 16
# Current temperature for city:
# Latest Temperature: 16°C
# Doha Rolling Average (last 5 readings): 28.00°C
# [PROCESS] Average Temperature Updated: 24.285714285714285
# [SIMULATION] Latest Temperature Updated: 38
# Current temperature for city:
# Latest Temperature: 38°C
# Doha Rolling Average (last 5 readings): 27.07°C
# [SIMULATION] Latest Temperature Updated: 19
# Current temperature for city:
# Latest Temperature: 19°C
# Doha Rolling Average (last 5 readings): 27.07°C
# [SIMULATION] Latest Temperature Updated: 28
# Current temperature for city:
# Latest Temperature: 28°C
# Doha Rolling Average (last 5 readings): 29.26°C
# [SIMULATION] Latest Temperature Updated: 17
# Current temperature for city:
# Latest Temperature: 17°C
# Doha Rolling Average (last 5 readings): 29.18°C
# [SIMULATION] Latest Temperature Updated: 40
# Current temperature for city:
# Latest Temperature: 40°C
# Doha Rolling Average (last 5 readings): 26.62°C
# [PROCESS] Average Temperature Updated: 25.571428571428573
# [SIMULATION] Latest Temperature Updated: 38
# Current temperature for city:
# Latest Temperature: 38°C
# Doha Rolling Average (last 5 readings): 26.36°C
# [SIMULATION] Latest Temperature Updated: 37
# Current temperature for city:
# Latest Temperature: 37°C
# Doha Rolling Average (last 5 readings): 26.36°C
# [SIMULATION] Latest Temperature Updated: 22
# Current temperature for city:
# Latest Temperature: 22°C
# Doha Rolling Average (last 5 readings): 28.69°C
# [SIMULATION] Latest Temperature Updated: 16
# Current temperature for city:
# Latest Temperature: 16°C
# Doha Rolling Average (last 5 readings): 28.29°C
# [SIMULATION] Latest Temperature Updated: 23
# Current temperature for city:
# Latest Temperature: 23°C
# Doha Rolling Average (last 5 readings): 25.20°C
# [PROCESS] Average Temperature Updated: 25.285714285714285
# [SIMULATION] Latest Temperature Updated: 16
# Current temperature for city:
# Latest Temperature: 16°C
# Doha Rolling Average (last 5 readings): 25.22°C
# [SIMULATION] Latest Temperature Updated: 36
# Current temperature for city:
# Latest Temperature: 36°C
# Doha Rolling Average (last 5 readings): 25.22°C
# [SIMULATION] Latest Temperature Updated: 20
# Current temperature for city:
# Latest Temperature: 20°C
# Doha Rolling Average (last 5 readings): 23.37°C
# [SIMULATION] Latest Temperature Updated: 34
# Current temperature for city:
# Latest Temperature: 34°C
# Doha Rolling Average (last 5 readings): 26.34°C
# [SIMULATION] Latest Temperature Updated: 16
# Current temperature for city:
# Latest Temperature: 16°C
# Doha Rolling Average (last 5 readings): 28.89°C
# [PROCESS] Average Temperature Updated: 32.142857142857146
# [SIMULATION] Latest Temperature Updated: 36
# Current temperature for city:
# Latest Temperature: 36°C
# Doha Rolling Average (last 5 readings): 29.70°C
# [SIMULATION] Latest Temperature Updated: 21
# Current temperature for city:
# Latest Temperature: 21°C
# Doha Rolling Average (last 5 readings): 29.70°C
# [SIMULATION] Latest Temperature Updated: 16
# Current temperature for city:
# Latest Temperature: 16°C
# Doha Rolling Average (last 5 readings): 30.96°C
# [SIMULATION] Latest Temperature Updated: 33
# Current temperature for city:
# Latest Temperature: 33°C
# Doha Rolling Average (last 5 readings): 28.48°C
# [SIMULATION] Latest Temperature Updated: 32
# Current temperature for city:
# Latest Temperature: 32°C
# Doha Rolling Average (last 5 readings): 29.65°C
# [PROCESS] Average Temperature Updated: 26.857142857142858
# [SIMULATION] Latest Temperature Updated: 19
# Current temperature for city:
# Latest Temperature: 19°C
# Doha Rolling Average (last 5 readings): 28.96°C
# [SIMULATION] Latest Temperature Updated: 24
# Current temperature for city:
# Latest Temperature: 24°C
# Doha Rolling Average (last 5 readings): 28.96°C
# [SIMULATION] Latest Temperature Updated: 17
# Current temperature for city:
# Latest Temperature: 17°C
# Doha Rolling Average (last 5 readings): 26.96°C
# [SIMULATION] Latest Temperature Updated: 17
# Current temperature for city:
# Latest Temperature: 17°C
# Doha Rolling Average (last 5 readings): 27.58°C
# [SIMULATION] Latest Temperature Updated: 17
# Current temperature for city:
# Latest Temperature: 17°C
# Doha Rolling Average (last 5 readings): 24.72°C
# [PROCESS] Average Temperature Updated: 24.428571428571427
# [SIMULATION] Latest Temperature Updated: 39
# Current temperature for city:
# Latest Temperature: 39°C
# Doha Rolling Average (last 5 readings): 24.65°C
# [SIMULATION] Latest Temperature Updated: 35
# Current temperature for city:
# Latest Temperature: 35°C
# Doha Rolling Average (last 5 readings): 24.65°C
# [SIMULATION] Latest Temperature Updated: 36
# Current temperature for city:
# Latest Temperature: 36°C
# Doha Rolling Average (last 5 readings): 27.52°C
# [SIMULATION] Latest Temperature Updated: 25
# Current temperature for city:
# Latest Temperature: 25°C
# Doha Rolling Average (last 5 readings): 28.86°C
# [SIMULATION] Latest Temperature Updated: 37
# Current temperature for city:
# Latest Temperature: 37°C
# Doha Rolling Average (last 5 readings): 28.24°C
# [PROCESS] Average Temperature Updated: 31.142857142857142
# [SIMULATION] Latest Temperature Updated: 34
# Current temperature for city:
# Latest Temperature: 34°C
# Doha Rolling Average (last 5 readings): 28.97°C
# [SIMULATION] Latest Temperature Updated: 24
# Current temperature for city:
# Latest Temperature: 24°C
# Doha Rolling Average (last 5 readings): 28.97°C
# [SIMULATION] Latest Temperature Updated: 22
# Current temperature for city:
# Latest Temperature: 22°C
# Doha Rolling Average (last 5 readings): 29.97°C
# [SIMULATION] Latest Temperature Updated: 36
# Current temperature for city:
# Latest Temperature: 36°C
# Doha Rolling Average (last 5 readings): 29.29°C
# [SIMULATION] Latest Temperature Updated: 33
# Current temperature for city:
# Latest Temperature: 33°C
# Doha Rolling Average (last 5 readings):
C
# [SIMULATION] Latest Temperature Updated: 21
# Current temperature for city:
# Latest Temperature: 39°C
# Doha Rolling Average (last 5 readings): 25.78°C
# [SIMULATION] Latest Temperature Updated: 34
# [PROCESS] Average Temperature Updated: 32.888888888888886
# Current temperature for city:
# Latest Temperature: 24°C
# Doha Rolling Average (last 5 readings): 27.20°C
# [SIMULATION] Latest Temperature Updated: 32
# Current temperature for city:
# Latest Temperature: 17°C
# Doha Rolling Average (last 5 readings): 28.88°C
# [SIMULATION] Latest Temperature Updated: 21
# Current temperature for city:
# Latest Temperature: 18°C
# Doha Rolling Average (last 5 readings): 28.88°C
# [SIMULATION] Latest Temperature Updated: 38
# Current temperature for city:
# Latest Temperature: 40°C
# Doha Rolling Average (last 5 readings): 27.68°C
# [SIMULATION] Latest Temperature Updated: 26
# Current temperature for city:
# Latest Temperature: 28°C
# Doha Rolling Average (last 5 readings): 27.68°C
# [SIMULATION] Latest Temperature Updated: 40
# [PROCESS] Average Temperature Updated: 32.2
# Current temperature for city:
# Latest Temperature: 34°C
# Doha Rolling Average (last 5 readings): 28.81°C
# [SIMULATION] Latest Temperature Updated: 31
# Current temperature for city:
# Latest Temperature: 34°C
# Doha Rolling Average (last 5 readings): 28.27°C
# [SIMULATION] Latest Temperature Updated: 29
# Current temperature for city:
# Latest Temperature: 27°C
# Doha Rolling Average (last 5 readings): 28.27°C
# [SIMULATION] Latest Temperature Updated: 17
# Current temperature for city:
# Latest Temperature: 20°C
# Doha Rolling Average (last 5 readings): 27.52°C
# [SIMULATION] Latest Temperature Updated: 26
# Current temperature for city:
# Latest Temperature: 30°C
# Doha Rolling Average (last 5 readings): 27.52°C
# [SIMULATION] Latest Temperature Updated: 24
# [PROCESS] Average Temperature Updated: 25.4
# Current temperature for city:
# Latest Temperature: 25°C
# Doha Rolling Average (last 5 readings): 26.99°C
# [SIMULATION] Latest Temperature Updated: 17
# Current temperature for city:
# Latest Temperature: 39°C
# Doha Rolling Average (last 5 readings): 25.59°C
# [SIMULATION] Latest Temperature Updated: 29
# Current temperature for city:
# Latest Temperature: 27°C
# Doha Rolling Average (last 5 readings): 25.59°C
# [SIMULATION] Latest Temperature Updated: 38
# Current temperature for city:
# Latest Temperature: 22°C
# Doha Rolling Average (last 5 readings): 28.14°C
# [SIMULATION] Latest Temperature Updated: 38
# Current temperature for city:
# Latest Temperature: 22°C
# Doha Rolling Average (last 5 readings): 28.14°C
# [SIMULATION] Latest Temperature Updated: 34
# [PROCESS] Average Temperature Updated: 28.4
# Current temperature for city:
# Latest Temperature: 33°C
# Doha Rolling Average (last 5 readings): 28.20°C
# [SIMULATION] Latest Temperature Updated: 33
# Current temperature for city:
# Latest Temperature: 26°C
# Doha Rolling Average (last 5 readings): 29.40°C
# [SIMULATION] Latest Temperature Updated: 15
# Current temperature for city:
# Latest Temperature: 39°C
# Doha Rolling Average (last 5 readings): 29.40°C
# [SIMULATION] Latest Temperature Updated: 18
# Current temperature for city:
# Latest Temperature: 18°C
# Doha Rolling Average (last 5 readings): 28.80°C
# [SIMULATION] Latest Temperature Updated: 31
# Current temperature for city:
# Latest Temperature: 16°C
# Doha Rolling Average (last 5 readings): 28.80°C
# [SIMULATION] Latest Temperature Updated: 29
# [PROCESS] Average Temperature Updated: 27.9
# Current temperature for city:
# Latest Temperature: 26°C
# Doha Rolling Average (last 5 readings): 28.58°C
# [SIMULATION] Latest Temperature Updated: 21
# Current temperature for city:
# Latest Temperature: 22°C
# Doha Rolling Average (last 5 readings): 27.58°C
# [SIMULATION] Latest Temperature Updated: 38
# Current temperature for city:
# Latest Temperature: 29°C
# Doha Rolling Average (last 5 readings): 27.58°C
# [SIMULATION] Latest Temperature Updated: 32
# Current temperature for city:
# Latest Temperature: 34°C
# Doha Rolling Average (last 5 readings): 25.82°C
# [SIMULATION] Latest Temperature Updated: 28
# Current temperature for city:
# Latest Temperature: 21°C
# Doha Rolling Average (last 5 readings): 25.82°C
# [SIMULATION] Latest Temperature Updated: 17
# [PROCESS] Average Temperature Updated: 28.0
# Current temperature for city:
# Latest Temperature: 17°C
# Doha Rolling Average (last 5 readings): 26.37°C
# [SIMULATION] Latest Temperature Updated: 24
# Current temperature for city:
# Latest Temperature: 25°C
# Doha Rolling Average (last 5 readings): 25.38°C
# [SIMULATION] Latest Temperature Updated: 34
# Current temperature for city:
# Latest Temperature: 26°C
# Doha Rolling Average (last 5 readings): 25.86°C
# [SIMULATION] Latest Temperature Updated: 20
# Current temperature for city:
# Latest Temperature: 18°C
# Doha Rolling Average (last 5 readings): 26.04°C
# [SIMULATION] Latest Temperature Updated: 30
# Current temperature for city:
# Latest Temperature: 15°C
# Doha Rolling Average (last 5 readings): 26.04°C
# [SIMULATION] Latest Temperature Updated: 21
# [PROCESS] Average Temperature Updated: 24.1
# Current temperature for city:
# Latest Temperature: 16°C
# Doha Rolling Average (last 5 readings): 25.55°C
# [SIMULATION] Latest Temperature Updated: 38
